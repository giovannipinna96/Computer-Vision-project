# %% [markdown]
# # FIRST ATTEMPT TO CNN

# %% [markdown]
# The purpose of this first file is to implement a Convolutional Neural Network able to classify the images in the different classes with an accuracy of at least 30%.
#
# Initially, the data must be read and pre-processed. In general it is necessary to convert the images to grayscale and resize the various images to 64x64 pixels.

# %% [markdown]
# ## Libreries

# %% [markdown]
# List of list of libraries used

# %%
import os
import glob
import cv2 as cv2
import numpy as np
import keras as ks
import matplotlib.pyplot as plt
import tensorflow as tf
import seaborn as sn

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, Flatten, MaxPooling2D, Activation
from tensorflow.keras.callbacks import EarlyStopping
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import classification_report, confusion_matrix

import import_ipynb
import dataSetUtility as dsu
import plottingUtility as pltu
# Out:
# importing Jupyter notebook from dataSetUtility.ipynb
# importing Jupyter notebook from plottingUtility.ipynb

# %% [markdown]
# ## DATA PREPROCESSING

# %% [markdown]
# In the following cells we construct and prepare the data for CNN. We read all images and resize it.

# %%
#path to the directories
pathTrain=r'C:\Users\39320\Desktop\computer vision\Computer-Vision-2020-main\ImageSet\train'
pathTest=r'C:\Users\39320\Desktop\computer vision\Computer-Vision-2020-main\ImageSet\test'

labels = [os.path.basename(i) for i in glob.glob(pathTrain + '/*', recursive=True)]
numberOfClasses = len(labels)
print("Class number: ", numberOfClasses)
print("Class names: ", labels)
# Out:
# Class number:  15
# Class names:  ['Bedroom', 'Coast', 'Forest', 'Highway', 'Industrial', 'InsideCity', 'Kitchen', 'LivingRoom', 'Mountain', 'Office', 'OpenCountry', 'Store', 'Street', 'Suburb', 'TallBuilding']

# %%
xTrainRaw, yTrainRaw = dsu.loadImages(pathTrain, labels)
xTest, yTest = dsu.loadImages(pathTest, labels)

print('len train x: ',len(xTrainRaw))
print('len test x: ',len(xTest))
print('len train y: ',len(yTrainRaw))
print('len test y: ',len(yTest))
# Out:
# len train x:  1500
# len test x:  2985
# len train y:  1500
# len test y:  2985

# %% [markdown]
# Convert the labels into a set of numbers to input into the neural net work

# %%
yTrainCategorical = to_categorical(yTrainRaw)
yTestCategorical = to_categorical(yTest)

# %% [markdown]
# Split the training set into train set (85%) and validation set (15%)

# %%
xTrain, xValidation, yTrain, yValidation = train_test_split(xTrainRaw, yTrainCategorical, train_size=0.85, random_state=275)
print('len Train Set: ',len(xTrain))
print('len Validation Set: ',len(xValidation))
print('len Test Set: ',len(xTest))
# Out:
# len Train Set:  1275
# len Validation Set:  225
# len Test Set:  2985

# %% [markdown]
# # CNN MODEL

# %% [markdown]
# To buil the model we need to create the architecture and add the layer to extract features from the input images.

# %%
sgd = tf.keras.optimizers.SGD(momentum=0.9,nesterov=True)
norm = ks.initializers.RandomNormal(mean=0.0, stddev=0.01, seed=None)
baseModel = Sequential([
    #first convolutional layer
    Conv2D(8, 3,strides=1, padding='valid', activation='relu', input_shape=(64,64,1)),
    MaxPooling2D(pool_size=2,strides=2),
    
    #second convolutional layer
    Conv2D(16, 3,strides=1, padding='valid',activation='relu'),
    MaxPooling2D(pool_size=2,strides=2),
    
    #third convolutional layer
    Conv2D(32, 3,strides=1, padding='valid',activation='relu'),
    Flatten(),
    Dense(numberOfClasses, activation='relu',kernel_initializer=norm, bias_initializer='zeros'),
    Dense(numberOfClasses, activation='softmax')
])

baseModel.compile(loss='categorical_crossentropy', optimizer=sgd, metrics = ['accuracy'])

# %%
baseModel.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 62, 62, 8)         80
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 31, 31, 8)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 29, 29, 16)        1168
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 14, 14, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 12, 12, 32)        4640
# _________________________________________________________________
# flatten (Flatten)            (None, 4608)              0
# _________________________________________________________________
# dense (Dense)                (None, 15)                69135
# _________________________________________________________________
# dense_1 (Dense)              (None, 15)                240
# =================================================================
# Total params: 75,263
# Trainable params: 75,263
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # MODEL TRANING AND TESTING

# %% [markdown]
# Now we train our CNN and visualizze the training results. We also implement the earlystopping in order to stop the training before the end of epochs if it is necessary

# %%
earlyStopping = EarlyStopping(min_delta=0.10,patience = 10, monitor='val_loss')

history=baseModel.fit(xTrain, yTrain, 
                      batch_size=32,epochs=100,
                      validation_data=(xValidation, yValidation),
                      shuffle=True,callbacks=[earlyStopping])
# Out:
# Epoch 1/100
# 40/40 [==============================] - 2s 32ms/step - loss: 2.7089 - accuracy: 0.0690 - val_loss: 2.7079 - val_accuracy: 0.0489
# Epoch 2/100
# 40/40 [==============================] - 1s 26ms/step - loss: 2.7067 - accuracy: 0.0761 - val_loss: 2.7064 - val_accuracy: 0.0756
# Epoch 3/100
# 40/40 [==============================] - 1s 28ms/step - loss: 2.7015 - accuracy: 0.0753 - val_loss: 2.6986 - val_accuracy: 0.0978
# Epoch 4/100
# 40/40 [==============================] - 1s 28ms/step - loss: 2.6813 - accuracy: 0.1208 - val_loss: 2.6600 - val_accuracy: 0.0978
# Epoch 5/100
# 40/40 [==============================] - 1s 26ms/step - loss: 2.6205 - accuracy: 0.1122 - val_loss: 2.5451 - val_accuracy: 0.1067
# Epoch 6/100
# 40/40 [==============================] - 1s 26ms/step - loss: 2.5019 - accuracy: 0.1686 - val_loss: 2.3938 - val_accuracy: 0.2133
# Epoch 7/100
# 40/40 [==============================] - 1s 25ms/step - loss: 2.7239 - accuracy: 0.0808 - val_loss: 2.7164 - val_accuracy: 0.0667
# Epoch 8/100
# 40/40 [==============================] - 1s 25ms/step - loss: 2.7101 - accuracy: 0.0667 - val_loss: 2.7159 - val_accuracy: 0.0667
# Epoch 9/100
# 40/40 [==============================] - 1s 26ms/step - loss: 2.7086 - accuracy: 0.0643 - val_loss: 2.7146 - val_accuracy: 0.0711
# Epoch 10/100
# 40/40 [==============================] - 1s 27ms/step - loss: 2.7075 - accuracy: 0.0635 - val_loss: 2.7134 - val_accuracy: 0.0356
# Epoch 11/100
# 40/40 [==============================] - 1s 26ms/step - loss: 2.7060 - accuracy: 0.0620 - val_loss: 2.7100 - val_accuracy: 0.0400
# Epoch 12/100
# 40/40 [==============================] - 1s 28ms/step - loss: 2.7033 - accuracy: 0.0675 - val_loss: 2.7062 - val_accuracy: 0.0533
# Epoch 13/100
# 40/40 [==============================] - 1s 30ms/step - loss: 2.6899 - accuracy: 0.1027 - val_loss: 2.6642 - val_accuracy: 0.1689
# Epoch 14/100
# 40/40 [==============================] - 1s 26ms/step - loss: 2.5555 - accuracy: 0.1435 - val_loss: 2.4670 - val_accuracy: 0.1911
# Epoch 15/100
# 40/40 [==============================] - 1s 27ms/step - loss: 2.3919 - accuracy: 0.2039 - val_loss: 2.3202 - val_accuracy: 0.2178
# Epoch 16/100
# 40/40 [==============================] - 1s 26ms/step - loss: 2.2772 - accuracy: 0.2392 - val_loss: 2.2750 - val_accuracy: 0.2533
# Epoch 17/100
# 40/40 [==============================] - 1s 26ms/step - loss: 2.1792 - accuracy: 0.2902 - val_loss: 2.2818 - val_accuracy: 0.2756
# Epoch 18/100
# 40/40 [==============================] - 1s 25ms/step - loss: 2.0174 - accuracy: 0.3365 - val_loss: 2.1421 - val_accuracy: 0.3022
# Epoch 19/100
# 40/40 [==============================] - 1s 26ms/step - loss: 1.8685 - accuracy: 0.3898 - val_loss: 2.2585 - val_accuracy: 0.2978
# Epoch 20/100
# 40/40 [==============================] - 1s 26ms/step - loss: 1.6968 - accuracy: 0.4463 - val_loss: 2.0659 - val_accuracy: 0.3333
# Epoch 21/100
# 40/40 [==============================] - 1s 27ms/step - loss: 1.5366 - accuracy: 0.4871 - val_loss: 2.0735 - val_accuracy: 0.3867
# Epoch 22/100
# 40/40 [==============================] - 1s 25ms/step - loss: 1.2823 - accuracy: 0.5678 - val_loss: 2.0602 - val_accuracy: 0.3956
# Epoch 23/100
# 40/40 [==============================] - 1s 25ms/step - loss: 0.9904 - accuracy: 0.6753 - val_loss: 2.2957 - val_accuracy: 0.3689
# Epoch 24/100
# 40/40 [==============================] - 1s 31ms/step - loss: 0.7946 - accuracy: 0.7255 - val_loss: 2.4523 - val_accuracy: 0.3911
# Epoch 25/100
# 40/40 [==============================] - 1s 31ms/step - loss: 0.5543 - accuracy: 0.8110 - val_loss: 2.8846 - val_accuracy: 0.3111
# Epoch 26/100
# 40/40 [==============================] - 1s 35ms/step - loss: 0.3791 - accuracy: 0.8816 - val_loss: 2.8163 - val_accuracy: 0.3733
# Epoch 27/100
# 40/40 [==============================] - 1s 26ms/step - loss: 0.2398 - accuracy: 0.9302 - val_loss: 3.3216 - val_accuracy: 0.3556
# Epoch 28/100
# 40/40 [==============================] - 1s 25ms/step - loss: 0.1604 - accuracy: 0.9592 - val_loss: 3.4698 - val_accuracy: 0.3689

# %% [markdown]
# Valuate the model and predict a classes

# %%
baseModel.evaluate(xTest, yTestCategorical)
#predict classes
prediction = baseModel.predict(xTest)

#safe only best class for all prediction 
yPred = dsu.predictClass(prediction)
# Out:
# 94/94 [==============================] - 1s 8ms/step - loss: 3.2441 - accuracy: 0.3715

# %% [markdown]
# We now obtain the confusion matrix

# %%
cm=confusion_matrix(yTest, yPred)

# %% [markdown]
# # PLOTTING

# %% [markdown]
# In the remaining cells We perform some plots that can be interested to comment

# %%
pltu.plotConfusionMatrix(cm, labels, "confusion_matrix_1", "images_point_one/")

# %%
pltu.validationLoss(history, "images_point_one")

# %%
pltu.validationAccuracy(history, "images_point_one")

# %%
pltu.plottingAccuracy(history, "images_point_one")

# %%
pltu.plottingLoss(history, "images_point_one")

# %%
print('Classification Report')
print(classification_report(yTest, yPred, target_names=labels))
# Out:
# Classification Report
#               precision    recall  f1-score   support
#
#      Bedroom       0.22      0.24      0.23       116
#        Coast       0.55      0.70      0.62       260
#       Forest       0.56      0.45      0.50       228
#      Highway       0.59      0.51      0.54       160
#   Industrial       0.28      0.22      0.25       211
#   InsideCity       0.15      0.12      0.14       208
#      Kitchen       0.14      0.37      0.21       110
#   LivingRoom       0.30      0.26      0.28       189
#     Mountain       0.29      0.48      0.36       274
#       Office       0.22      0.28      0.24       115
#  OpenCountry       0.45      0.35      0.39       310
#        Store       0.40      0.23      0.29       215
#       Street       0.56      0.48      0.52       192
#       Suburb       0.47      0.46      0.47       141
# TallBuilding       0.51      0.30      0.37       256
#
#     accuracy                           0.37      2985
#    macro avg       0.38      0.36      0.36      2985
# weighted avg       0.40      0.37      0.37      2985

# %% [markdown]
# # Conclusion First Point

# %% [markdown]
# With this CNN we have an accuracy of 35%. The next goal is to improve this result.
